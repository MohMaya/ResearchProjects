# %%
import cv2
import numpy as np
np.set_printoptions(threshold=np.nan)
from matplotlib import pyplot as plt
# %matplotlib inline
from math import ceil
from math import pow
from math import sqrt
from copy import deepcopy

# %%
image = cv2.imread('gray2.jpg',cv2.IMREAD_GRAYSCALE)
image_dash = cv2.imread('gray2.jpg',cv2.IMREAD_GRAYSCALE)

# %%
a=plt.subplot(121)
a.imshow(image,cmap='gray')
a.set_title("Original")
plt.xticks([]), plt.yticks([])
b=plt.subplot(122)
b.imshow(image_dash, cmap = 'gray')
b.set_title("Modified")
plt.xticks([]), plt.yticks([])
plt.show()

# %%
image_doubdash = image_dash.flatten()

# %%
imnew = np.reshape(np.asarray(image_doubdash),(128,128))

# %%
a=plt.subplot(121)
a.imshow(image[0:32,0:32],cmap='gray')
a.set_title("Original")
plt.xticks([]), plt.yticks([])
b=plt.subplot(122)
b.imshow(imnew[0:32,0:32], cmap = 'gray')
b.set_title("Modified")
plt.xticks([]), plt.yticks([])
plt.show()
