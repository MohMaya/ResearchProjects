# %%
import cv2
import numpy as np
np.set_printoptions(threshold=np.nan)
from matplotlib import pyplot as plt
# %matplotlib inline
from math import ceil
from math import pow
from math import sqrt
from copy import deepcopy

# %%
image = cv2.imread('gray2.jpg',cv2.IMREAD_GRAYSCALE)
image_dash = cv2.imread('gray2.jpg',cv2.IMREAD_GRAYSCALE)

# %%
x_checkpoint_pixels = []
y_checkpoint_pixels = []
number_of_blocks = 16
#Assuming the image to be square shaped
step_size = image_dash.shape[0]//int(sqrt(number_of_blocks))
for checkpoint in range(0,image_dash.shape[0],step_size):
    x_checkpoint_pixels.append(checkpoint)
    y_checkpoint_pixels.append(checkpoint)
x_checkpoint_pixels.append(image_dash.shape[0])
y_checkpoint_pixels.append(image_dash.shape[0])

print(x_checkpoint_pixels)
print(y_checkpoint_pixels)
# Out:
# [0, 32, 64, 96, 128]
# [0, 32, 64, 96, 128]

# %%
blockwise_pixels = []
for i in range(len(y_checkpoint_pixels)-1):
    for j in range(len(x_checkpoint_pixels)-1):
        blockwise_pixels.append(image_dash[x_checkpoint_pixels[j]:x_checkpoint_pixels[j+1],y_checkpoint_pixels[i]:y_checkpoint_pixels[i+1]])

# %%
pixels_of_block = []
for i in range(len(blockwise_pixels)):
    pixels_of_block.append(blockwise_pixels[i].flatten())

# %%
def s_calculator(pixels_in_a_block,block_number):
    cardinality_pixels_in_block = len(pixels_in_a_block)
    s=0
    for i in range(cardinality_pixels_in_block - 1):
       s = s + abs(pow(pixels_in_a_block[i],block_number)-pow(pixels_in_a_block[i+1],block_number))
    #print(s)
    s=s/(cardinality_pixels_in_block - 1)
    s=pow(s,1/block_number)
    #print(s)
    s=ceil(s)
    return s

# %%
s_values = []
for j in range(number_of_blocks):
    s_values.append(s_calculator(pixels_of_block[j],j+1))
print(s_values)
# Out:
# [9, 53, 76, 98, 101, 121, 127, 98, 154, 160, 156, 169, 175, 169, 172, 177]

# %%
def graph_maker(pixels_in_block,value_of_s):
    graph = {}
    cardinality_block = len(pixels_in_block)
    
    for i in range(cardinality_block):
        graph[i] = []
    for i in range(cardinality_block):
        for j in range(cardinality_block):
            if(i==j):
                continue
            elif(abs(int(pixels_in_block[i])-int(pixels_in_block[j]))<value_of_s):
                graph[i].append(j)
    return graph

# %%
graph_of_block = []
for k in range(number_of_blocks):
    graph_of_block.append(graph_maker(pixels_of_block[k],s_values[k]))

# %%
def compare_print(arr1,arr2):
    for m in range(len(arr1)):
        print(arr1[m],arr2[m])

# %%
def hide_a_message(message,block_number):
    graph_dash = deepcopy(graph_of_block[block_number])
    print('copy successful')
    stop = False
    i=0
    c=0
    while not stop :
        #print('iteration ',c,'with i = ',i,end="")
        #c+=1
        if(len(graph_dash[i])>0):
            j = min(graph_dash[i])
            del graph_dash[j]
            for k in graph_dash:
                if(j in graph_dash[k]):
                    graph_dash[k].remove(j)
            #print(' and removed : ',j)
        else:
            q=[]
            for k in graph_dash:
                if k > i:
                    q.append(k)
            if(len(q)>0):
                i_dash = min(q)
                if(i_dash == max(graph_dash.keys())):
                    stop = True
                else:
                    i = i_dash
            else:
                stop = True
    
    print(2*len(graph_dash.keys()),' bits can be hidden')
    print('Nodes in color class : ',graph_dash.keys())
    new_pixels = deepcopy(pixels_of_block[block_number])
    #compare_print(new_pixels,pixels_of_block[block_number])
    for i in graph_dash.keys():
        c = len(message)
        if(c>0):
            pixel_value = bin(pixels_of_block[block_number][i])[2:]
            replacement = message[0:2]
            message = message[2:]
            c-=2
            print("IN ",pixel_value," last two are : ",pixel_value[-2:]," replaced by :",replacement)
            temp_pixel = ''
            temp_pixel+=pixel_value[:-2]
            temp_pixel+=replacement
            print(pixel_value," becomes : ",temp_pixel)
            for j in graph_of_block[block_number][i]:
                new_pixels[j]-=(int(pixel_value,2)-int(temp_pixel,2))
            new_pixels[i] -= (int(pixel_value,2)-int(temp_pixel,2)) 
            print(int(pixel_value,2)," becomes ",int(temp_pixel,2))
            #compare_print(new_pixels,pixels_of_block[block_number])
        else:
            print("\nmessage Finished")
            #compare_print(new_pixels,pixels_of_block[block_number])
            return new_pixels,1,message
    #compare_print(new_pixels,pixels_of_block[block_number])
    print('\nBlock Finished. Switching to new block')
    return new_pixels,0,message

# %%
def message_to_binary(message):
    final_message = []
    for i in message:
        final_message.append(bin(ord(i))[2:])
    for i in range(len(final_message)):
        if(len(final_message[i])<8):
            index_to_which_padding_done = len(final_message[i])
            temp = ''
            for j in range(8-len(final_message[i])):
                temp += '0'
            temp += final_message[i]
            final_message[i] = temp
    final_message_string = ''
    for i in final_message:
        final_message_string += i
    return final_message_string

# %%
message = 'Hello'
message = message+'#'
message_in_binary = message_to_binary(message)
finish = False
block_counter = 0
list_of_new_blocks = []
while(not finish):
    new_block, status, message_in_binary = hide_a_message(message_in_binary,block_counter)
    list_of_new_blocks.append(new_block)
    if(status == 1):  #finished the message
        finish = True
    else:#block finished
        block_counter += 1
#new_block = hide_a_message(message,0)
# Out:
# copy successful
# 26  bits can be hidden
# Nodes in color class :  dict_keys([0, 11, 14, 15, 16, 18, 31, 37, 78, 304, 529, 991, 1023])
# IN  10001001  last two are :  01  replaced by : 01
# 10001001  becomes :  10001001
# 137  becomes  137
# IN  10010111  last two are :  11  replaced by : 00
# 10010111  becomes :  10010100
# 151  becomes  148
# IN  1110110  last two are :  10  replaced by : 10
# 1110110  becomes :  1110110
# 118  becomes  118
# IN  1010110  last two are :  10  replaced by : 00
# 1010110  becomes :  1010100
# 86  becomes  84
# IN  111110  last two are :  10  replaced by : 01
# 111110  becomes :  111101
# 62  becomes  61
# IN  1001000  last two are :  00  replaced by : 10
# 1001000  becomes :  1001010
# 72  becomes  74
# IN  1100000  last two are :  00  replaced by : 01
# 1100000  becomes :  1100001
# 96  becomes  97
# IN  10000000  last two are :  00  replaced by : 01
# 10000000  becomes :  10000001
# 128  becomes  129
# IN  1101101  last two are :  01  replaced by : 01
# 1101101  becomes :  1101101
# 109  becomes  109
# IN  110101  last two are :  01  replaced by : 10
# 110101  becomes :  110110
# 53  becomes  54
# IN  101100  last two are :  00  replaced by : 11
# 101100  becomes :  101111
# 44  becomes  47
# IN  10100001  last two are :  01  replaced by : 00
# 10100001  becomes :  10100000
# 161  becomes  160
# IN  10111000  last two are :  00  replaced by : 01
# 10111000  becomes :  10111001
# 184  becomes  185
#
# Block Finished. Switching to new block
# copy successful
# 6  bits can be hidden
# Nodes in color class :  dict_keys([0, 8, 31])
# IN  111101  last two are :  01  replaced by : 10
# 111101  becomes :  111110
# 61  becomes  62
# IN  1111011  last two are :  11  replaced by : 11
# 1111011  becomes :  1111011
# 123  becomes  123
# IN  11000010  last two are :  10  replaced by : 00
# 11000010  becomes :  11000000
# 194  becomes  192
#
# Block Finished. Switching to new block
# copy successful
# 4  bits can be hidden
# Nodes in color class :  dict_keys([0, 9])
# IN  1000011  last two are :  11  replaced by : 01
# 1000011  becomes :  1000001
# 67  becomes  65
# IN  10010000  last two are :  00  replaced by : 10
# 10010000  becomes :  10010010
# 144  becomes  146
#
# Block Finished. Switching to new block
# copy successful
# 4  bits can be hidden
# Nodes in color class :  dict_keys([0, 8])
# IN  10011  last two are :  11  replaced by : 11
# 10011  becomes :  10011
# 19  becomes  19
# IN  1111001  last two are :  01  replaced by : 11
# 1111001  becomes :  1111011
# 121  becomes  123
#
# Block Finished. Switching to new block
# copy successful
# 2  bits can be hidden
# Nodes in color class :  dict_keys([0])
# IN  1100100  last two are :  00  replaced by : 00
# 1100100  becomes :  1100100
# 100  becomes  100
#
# Block Finished. Switching to new block
# copy successful
# 4  bits can be hidden
# Nodes in color class :  dict_keys([0, 794])
# IN  10000001  last two are :  01  replaced by : 10
# 10000001  becomes :  10000010
# 129  becomes  130
# IN  110  last two are :  10  replaced by : 00
# 110  becomes :  100
# 6  becomes  4
#
# Block Finished. Switching to new block
# copy successful
# 4  bits can be hidden
# Nodes in color class :  dict_keys([0, 178])
# IN  10000100  last two are :  00  replaced by : 11
# 10000100  becomes :  10000111
# 132  becomes  135
#
# message Finished

# %%
counter = 0
for i in range(len(y_checkpoint_pixels)-1):
    for j in range(len(x_checkpoint_pixels)-1):
        if(counter >= len(list_of_new_blocks)):
            break
        #print('a')
        image_dash[x_checkpoint_pixels[j]:x_checkpoint_pixels[j+1],y_checkpoint_pixels[i]:y_checkpoint_pixels[i+1]] = np.reshape(np.asarray(list_of_new_blocks[counter]),(step_size,step_size))
        counter += 1

# %%
a=plt.subplot(121)
a.imshow(image,cmap='gray')
a.set_title("Original")
plt.xticks([]), plt.yticks([])
b=plt.subplot(122)
b.imshow(image_dash, cmap = 'gray')
b.set_title("Modified")
plt.xticks([]), plt.yticks([])
plt.show()

# %%
image[0][0]
# Out:
# 137

# %%
image_dash[0][0]
# Out:
# 137

# %%
print(image_dash.shape)
# Out:
# (128, 128)

# %%
#SUCCESS AT LAST
cv2.imwrite('gray2_encoded.jpg',image_dash)
# Out:
# True
