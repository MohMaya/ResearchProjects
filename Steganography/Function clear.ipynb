# %%
import numpy as np
np.set_printoptions(threshold=np.nan)
from math import ceil
from math import pow
from math import sqrt
from copy import deepcopy

# %%
def hide(message,px,block_no):
    #Calculate s for given pixel set
    card_px = len(px)
    s=0
    for i in range(card_px-1):
        s = s + pow(abs(px[i]-px[i+1]),block_no)
    s=s/(card_px-1)
    s=ceil(s)
    
    print('s = ',s)
    valid = []
    
    
    #Create a graph for given pixel set
    grf = {}
    for i in range(card_px):
        grf[i]=[]
        valid.append(1)
    for i in range(card_px):
        for j in range(card_px):
            if(i==j):
                continue
            elif(abs(px[i]-px[j])<s):
                grf[i].append(j)

    
    #Calculate the nodes(index of pixels) in grf that belong to maximal independent set
    grf_dash = deepcopy(grf)
    stop = False
    i=0
    while not stop :
        if(len(grf_dash[i])>0):
            j = min(grf_dash[i])
            del grf_dash[j]
            valid[j]=0
            for k in grf_dash:
                if(j in grf_dash[k]):
                    grf_dash[k].remove(j)
        else:
            q=[]
            for k in grf_dash:
                if k > i:
                    q.append(k)
            if(len(q)>0):
                i_dash = min(q)
                if(i_dash == max(grf_dash.keys())):
                    stop = True
                else:
                    i = i_dash
            else:
                stop = True
    
    print(grf_dash.keys())
    
    
    #Get new pixel values by replacing the last bits by message
    new_pixels = deepcopy(px)
    keys = list(grf_dash.keys())
    for i in keys[:4]:
        c = len(message)
        if(c>0):
            pixel_value = bin(px[i])[2:]
            replacement = message[0:2]
            message = message[2:]
            c-=2
            print('Pixel Value(Integer)              : ',px[i])
            print('Pixel Value(Binary,Before)        : ',pixel_value)
            print('Message bits to be hidden         : ',replacement)
            print('Remaining Message : ',message)
            print("               ",pixel_value[-2:]," replaced by :",replacement)
            temp_pixel = ''
            temp_pixel+=pixel_value[:-2]
            temp_pixel+=replacement
            print('             ',pixel_value," becomes : ",temp_pixel)
            for j in (grf[i]):
                #print('Adjoining Pixel value at : ',j)
                #print('Changed from : ',new_pixels[j])
                #print('j = ',j)
                new_pixels[j]-=(int(pixel_value,2)-int(temp_pixel,2))
                #print('Changed To : ',new_pixels[j])
            new_pixels[i] = int(temp_pixel,2)
            print('           ',px[i]," successfully changed to ",new_pixels[i])
        else:
            print("\n##########MESSAGE FINISHED#################")
            return new_pixels
    print('\n***************Block Finished. Switching to new block***************')
    return new_pixels

# %%
def reveal(px):
    card_px = len(px)
    #print(px)
    s=0
    block_no = 1
    for i in range(card_px-1):
        #print(px[i],px[i+1])
        s = s + pow(abs(px[i]-px[i+1]),block_no)
    #print(s)
    s=s/(card_px-1)
    s=pow(s,1/block_no)
    #print(s)
    s=ceil(s)
    print('s = ',s)


    grf = {}

    for i in range(card_px):
        grf[i]=[]

    for i in range(card_px):
        for j in range(card_px):
            if(i==j):
                continue
            if(abs(px[i]-px[j])<s):
                grf[i].append(j)

    #for i in range(card_px):
     #   print("Nodes Related to node",i,":",grf[i])
    
    grf_dash = deepcopy(grf)
    stop = False
    i=0
    while not stop :
        if(len(grf_dash[i])>0):
            j = min(grf_dash[i])
            del grf_dash[j]
            for k in grf_dash:
                if(j in grf_dash[k]):
                    grf_dash[k].remove(j)
        else:
            q=[]
            for k in grf_dash:
                if k > i:
                    q.append(k)
            if(len(q)>0):
                i_dash = min(q)
                if(i_dash == max(grf_dash.keys())):
 67, 101, 125, 137, 138, 138, 138, 128, 104, 76, 44, 41, 51, 56, 59, 63, 63, 62, 65, 70, 71, 73, 75, 78, 62, 124, 58, 58, 59, 60, 59, 52, 69, 100, 122, 139, 141, 140, 137, 129, 107, 72, 42, 39, 49, 59, 62, 64, 65, 64, 64, 67, 71, 70, 76, 76, 66, 161, 60, 60, 60, 62, 61, 55, 68, 98, 122, 140, 145, 144, 140, 128, 106, 72, 44, 43, 49, 60, 65, 65, 67, 65, 66, 67, 70, 75, 77, 78, 79, 184]
reveal(orig_pixel)
# Out:
# s =  9
# keys in grf_dash :  dict_keys([0, 11, 14, 15, 16, 18, 31, 37, 78, 304, 529, 991, 1023])
# Integer Pixel Value :  137
# Binary Pixel Value  :  10001001
# Integer Pixel Value :  151
# Binary Pixel Value  :  10010111
# Integer Pixel Value :  118
# Binary Pixel Value  :  1110110
# Integer Pixel Value :  86
# Binary Pixel Value  :  1010110
# Integer Pixel Value :  62
# Binary Pixel Value  :  111110
# Integer Pixel Value :  72
# Binary Pixel Value  :  1001000
# Integer Pixel Value :  96
# Binary Pixel Value  :  1100000
# Integer Pixel Value :  128
# Binary Pixel Value  :  10000000
# Integer Pixel Value :  109
# Binary Pixel Value  :  1101101
# Integer Pixel Value :  53
# Binary Pixel Value  :  110101
# Integer Pixel Value :  44
# Binary Pixel Value  :  101100
# Integer Pixel Value :  161
# Binary Pixel Value  :  10100001
# Integer Pixel Value :  184
# Binary Pixel Value  :  10111000
# '01111010100000000101000100'

# %%
for j in range(len(hidden_pixels)):
    print(pixel[j],'  ',hidden_pixels[j])

# %%
print(pixel[37],hidden_pixels[37])
print(pixel[304],hidden_pixels[304])
print(pixel[529],hidden_pixels[529])
print(bin(pixel[37])[2:],bin(hidden_pixels[37])[2:])
print(bin(pixel[304])[2:],bin(hidden_pixels[304])[2:])
print(bin(pixel[529])[2:],bin(hidden_pixels[529])[2:])
# Out:
# 128 129
# 53 54
# 44 47
# 10000000 10000001
# 110101 110110
# 101100 101111

# %%
def graph_show(px,k,l):
    #Calculate s for given pixel set
    card_px = len(px)
    s=0
    block_no = 1
    for i in range(card_px-1):
        s = s + pow(abs(px[i]-px[i+1]),block_no)
    s=s/(card_px-1)
    s=ceil(s)
    print('px[',l,'] = ',px[l],'  px[',k,'] = ',px[k],sep='')
    print('s = ',s)
    valid = []
    #Create a graph for given pixel set
    grf = {}
    for i in range(card_px):
        grf[i]=[]
        valid.append(1)
    for i in range(card_px):
        for j in range(card_px):
            if(i==j):
                continue
            elif(abs(px[i]-px[j])<s):
                grf[i].append(j)
    print(grf[k])

# %%
graph_show(pixel,464,304)
# Out:
# px[304] = 53  px[464] = 47
# s =  9
# [81, 209, 241, 304, 305, 336, 337, 368, 369, 400, 401, 432, 433, 465, 496, 497, 517, 528, 529, 530, 549, 560, 561, 562, 580, 581, 592, 593, 594, 612, 613, 624, 625, 626, 643, 644, 645, 656, 657, 674, 675, 676, 677, 688, 689, 690, 706, 707, 708, 709, 720, 721, 737, 738, 740, 741, 752, 753, 769, 772, 773, 784, 785, 800, 805, 816, 817, 832, 848, 849, 869, 880, 881, 882, 901, 912, 913, 914, 933, 944, 945, 946, 965, 976, 977, 978, 997, 1008, 1009, 1010]
